# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

lista_alunos = pd.read_excel("alunos.xlsx")
lista_alunos["RA"] =  lista_alunos["RA"].astype(str) #transformar a coluna RA em string
print(lista_alunos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TURMA        26 non-null     object
#  1   ALUNO        26 non-null     object
#  2   LOGIN        26 non-null     object
#  3   RA           26 non-null     object
#  4   VERIFICAÇÃO  0 non-null      float64
# dtypes: float64(1), object(4)
# memory usage: 1.1+ KB
# None

# %%
navegador = webdriver.Chrome()
navegador.get("https://omnium.agilixbuzz.com/")
time.sleep(6)

for linha in range (0, 26): #preciso aprender como identificar a ultima linha da tabela
    try:
        navegador.find_element_by_xpath('/html/body/app-root/app-before-login/app-login/mat-toolbar/form/div/mat-form-field[1]/div/div[1]/div/input').send_keys(lista_alunos["LOGIN"][linha]) #login
        navegador.find_element_by_xpath('/html/body/app-root/app-before-login/app-login/mat-toolbar/form/div/mat-form-field[2]/div/div[1]/div/input').send_keys(lista_alunos["RA"][linha]) #senha
        navegador.find_element_by_xpath('/html/body/app-root/app-before-login/app-login/mat-toolbar/form/div/mat-form-field[1]/div/div[1]/div/input').send_keys(Keys.ENTER)
        time.sleep(2)
        navegador.find_element_by_xpath('/html/body/app-root/app-after-login/div/mat-sidenav-container/mat-sidenav-content/mat-toolbar/div[2]/button[2]').click() #menu
        lista_alunos.loc[linha, "VERIFICAÇÃO"] = "Verificado"  
        time.sleep(1)
    except:
        lista_alunos.loc[linha, "VERIFICAÇÃO"] = "Falha na verificação"
    try:
        navegador.find_element_by_xpath('/html/body/div[4]/div[2]/div/div/div/button[7]').click()#sair
    except:
        navegador.find_element_by_xpath('/html/body/div[3]/div[2]/div/div/div/button[7]').click()#sair, não entendi, algumas vezes o sair está na div[3]   
display(lista_alunos)
# Out:
#    TURMA                                    ALUNO                 LOGIN  \
# 0     2A          ANTHONY MAICON SANTOS CIRQUEIRA  SANTOANDRE/120095663
# 1     2A           BEATRIZ DE OLIVEIRA CAVALCANTI  SANTOANDRE/113834300
# 2     2A               CAMILLE DOS SANTOS CARETTI  SANTOANDRE/116366709
# 3     2A                   DAVI NUNES DE OLIVEIRA  SANTOANDRE/115760264
# 4     2A                DERYK RIAN DA SILVA NEVES  SANTOANDRE/116559068
# 5     2A         ENZO RAFAEL QUERICONI ALVES LIMA  SANTOANDRE/120082665
# 6     2A                   IGOR CARVALHO MERENCIO  SANTOANDRE/115686569
# 7     2A                   ISABELLA SOUSA MARTINS  SANTOANDRE/121141696
# 8     2A                   ISABELLE LIMA DA SILVA  SANTOANDRE/114358281
# 9     2A                  ISABELLY CARVALHO ALVES  SANTOANDRE/115300204
# 10    2A                 ISADORA NUNES DE ANDRADE  SANTOANDRE/115649488
# 11    2A                      JUAN GOMES DA CUNHA  SANTOANDRE/115411526
# 12    2A              JULIA RIBEIRO DE SOUZA REAL  SANTOANDRE/120914693
# 13    2A            KAUAN GABRIEL TOLEDO DA SILVA  SANTOANDRE/115135073
# 14    2A                  KAUANY GONCALVES VIEIRA  SANTOANDRE/120607219
# 15    2A  KAUANY KETILLY OLIVEIRA CANUTO DA SILVA  SANTOANDRE/115847777
# 16    2A                    LAIS SANTOS FERNANDES  SANTOANDRE/116310655
# 17    2A          LARISSA GIOVANI ARAUJO DA SILVA  SANTOANDRE/116762483
# 18    2A                    LAURA DA SILVA ARAUJO  SANTOANDRE/120145090
# 19    2A               LAVINIA RODRIGUES DA SILVA  SANTOANDRE/120145156
# 20    2A                      LETICIA SOUZA SILVA  SANTOANDRE/114341651
# 21    2A       MARIA CLARA GOMES DE SOUSA DE LIMA  SANTOANDRE/116630944
# 22    2A                  MIKAELLY MARCELA SANTOS  SANTOANDRE/115675122
# 23    2A                    PEDRO VICTOR DE ABREU  SANTOANDRE/114794367
# 24    2A       RAFAEL OLIVEIRA FERNANDES DA SILVA  SANTOANDRE/114553404
# 25    2A                  VICTOR DOS SANTOS COSTA  SANTOANDRE/120348707
#
#            RA VERIFICAÇÃO
# 0   120095663  Verificado
# 1   113834300  Verificado
# 2   116366709  Verificado
# 3   115760264  Verificado
# 4   116559068  Verificado
# 5   120082665  Verificado
# 6   115686569  Verificado
# 7   121141696  Verificado
# 8   114358281  Verificado
# 9   115300204  Verificado
# 10  115649488  Verificado
# 11  115411526  Verificado
# 12  120914693  Verificado
# 13  115135073  Verificado
# 14  120607219  Verificado
# 15  115847777  Verificado
# 16  116310655  Verificado
# 17  116762483  Verificado
# 18  120145090  Verificado
# 19  120145156  Verificado
# 20  114341651  Verificado
# 21  116630944  Verificado
# 22  115675122  Verificado
# 23  114794367  Verificado
# 24  114553404  Verificado
# 25  120348707  Verificado

# %%
navegador.quit()
lista_alunos.to_excel("alunos verificados.xlsx", index = False)
